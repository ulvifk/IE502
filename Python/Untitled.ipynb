# %%
import googlemaps

# %%
import pandas as pd
# Read Data
nodes = pd.read_csv("C:\\IE502QGIS\\Jupyter\\SolutionData\\Nodes.csv")
truckRoute = pd.read_csv("C:\\IE502QGIS\\Jupyter\\SolutionData\\TruckRoute.csv")
droneRoute = pd.read_csv("C:\\IE502QGIS\\Jupyter\\SolutionData\\DroneRoute.csv")
nodes
# Out:
#    Index          X          Y         Type
# 0      0  29.442315  40.805331        TRUCK
# 1      1  29.245976  40.969152  UAVELIGIBLE
# 2      2  29.250962  40.963022  UAVELIGIBLE
# 3      3  29.278775  40.977839  UAVELIGIBLE
# 4      4  28.851020  41.025410        TRUCK
# 5      5  28.852149  41.108290  UAVELIGIBLE
# 6      6  29.160179  41.171734        TRUCK
# 7      7  29.442315  40.805331        TRUCK

# %%
gmaps = googlemaps.Client(key='AIzaSyAKmjk7kc9H5SGC38ScgKsdC-6Gy1EXsXg')

# %%
location1 = [nodes["Y"][0], nodes["X"][0]]
location2 = [nodes["Y"][1], nodes["X"][1]]

gmaps.directions(origin = location1, destination=location2, mode="driving", units="metric")
# Out:
# [{'bounds': {'northeast': {'lat': 40.9733813, 'lng': 29.4770868},
#    'southwest': {'lat': 40.7990466, 'lng': 29.24542349999999}},
#   'copyrights': 'Map data ©2022 Google',
#   'legs': [{'distance': {'text': '34.1 km', 'value': 34053},
#     'duration': {'text': '30 mins', 'value': 1770},
#     'end_address': 'Hasanpaşa, Muradiye Sk. No:16, 34920 Sultanbeyli/İstanbul, Turkey',
#     'end_location': {'lat': 40.9689992, 'lng': 29.2459006},
#     'start_address': 'Arapçeşme, 1046/1. Sk. No:22, 41400 Gebze/Kocaeli, Turkey',
#     'start_location': {'lat': 40.80515949999999, 'lng': 29.4422506},
#     'steps': [{'distance': {'text': '0.1 km', 'value': 145},
#       'duration': {'text': '1 min', 'value': 41},
#       'end_location': {'lat': 40.805084, 'lng': 29.4439429},
#       'html_instructions': 'Head <b>east</b> on <b>1051/<wbr/>1. Sk.</b> toward <b>1044/<wbr/>1. Sk.</b>',
#       'polyline': {'points': 'gw`xFamurDJy@Hs@D_@@]?{@Ck@ASCWCQ'},
# ...

# %%
map = gmaps.map()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_22228/813375152.py in <module>
# ----> 1 map = gmaps.map()
#
# AttributeError: 'Client' object has no attribute 'map'
